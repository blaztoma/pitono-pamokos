# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/blaztoma/pitono-pamokos/blob/main/pamokos/20%20-%20Bibliotekos/2023-12-13%20-%20paskaita/2023_12_13_pandas_ir_matplotlib_ktu.ipynb)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# pd.read_excel('....')

# %%
duomenys = pd.read_csv('sf_paslaugos_prekes.csv')
duomenys
# Out:
#     idsf_paslaugos_prekes                 pavadinimas matavimo_vnt  vienetu  \
# 0                       1            Dizaino piešimas         val.      120
# 1                       2       Dizaino programavimas         val.      120
# 2                       3               Programavimas         val.      160
# 3                       4                  Testavimas         val.       16
# 4                       5               Programavimas         val.      160
# 5                       6                  Testavimas         val.       20
# 6                       7               Programavimas         val.      160
# 7                       8                  Testavimas         val.       20
# 8                       9               Programavimas         val.      160
# 9                      10                  Testavimas         val.       40
# 10                     11               Programavimas         val.      100
# ...

# %%
5 + 5
# Out:
# 10

# %%
"labas"
# Out:
# 'labas'

# %%
5 + 5
"labas"
# Out:
# 'labas'

# %%
duomenys['pavadinimas']
# Out:
# 0               Dizaino piešimas
# 1          Dizaino programavimas
# 2                  Programavimas
# 3                     Testavimas
# 4                  Programavimas
# 5                     Testavimas
# 6                  Programavimas
# 7                     Testavimas
# 8                  Programavimas
# 9                     Testavimas
# 10                 Programavimas
# 11                    Testavimas
# 12       Dokumentacijos rengimas
# 13    Projekto parengimas darbui
# 14              Dizaino piešimas
# 15         Dizaino programavimas
# 16                    Testavimas
# 17                 Programavimas
# 18                    Testavimas
# 19           Projekto talpinimas
# 20                       Avansas
# 21              Dizaino piešimas
# 22         Dizaino programavimas
# 23                    Testavimas
# 24                 Programavimas
# 25                    Testavimas
# 26           Projekto talpinimas
# Name: pavadinimas, dtype: object

# %%
duomenys['vienetu']
# Out:
# 0     120
# 1     120
# 2     160
# 3      16
# 4     160
# 5      20
# 6     160
# 7      20
# 8     160
# 9      40
# 10    100
# 11     40
# 12     50
# 13     30
# 14     80
# 15    120
# 16     20
# 17    100
# 18     20
# 19     20
# 20      1
# 21     80
# 22     80
# 23     20
# 24     80
# 25     10
# 26     10
# Name: vienetu, dtype: int64

# %%
duomenys[['pavadinimas', 'vienetu', 'vnt_kaina']]
# Out:
#                    pavadinimas  vienetu  vnt_kaina
# 0             Dizaino piešimas      120         40
# 1        Dizaino programavimas      120         40
# 2                Programavimas      160         40
# 3                   Testavimas       16         30
# 4                Programavimas      160         40
# 5                   Testavimas       20         30
# 6                Programavimas      160         40
# 7                   Testavimas       20         30
# 8                Programavimas      160         40
# 9                   Testavimas       40         30
# 10               Programavimas      100         40
# 11                  Testavimas       40         30
# 12     Dokumentacijos rengimas       50         30
# 13  Projekto parengimas darbui       30         30
# 14            Dizaino piešimas       80         40
# 15       Dizaino programavimas      120         40
# 16                  Testavimas       20         30
# ...

# %%
duomenys['bendra_kaina'] = duomenys['vienetu'] * duomenys['vnt_kaina']
duomenys
# Out:
#     idsf_paslaugos_prekes                 pavadinimas matavimo_vnt  vienetu  \
# 0                       1            Dizaino piešimas         val.      120
# 1                       2       Dizaino programavimas         val.      120
# 2                       3               Programavimas         val.      160
# 3                       4                  Testavimas         val.       16
# 4                       5               Programavimas         val.      160
# 5                       6                  Testavimas         val.       20
# 6                       7               Programavimas         val.      160
# 7                       8                  Testavimas         val.       20
# 8                       9               Programavimas         val.      160
# 9                      10                  Testavimas         val.       40
# 10                     11               Programavimas         val.      100
# ...

# %%
duomenys.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   idsf_paslaugos_prekes  27 non-null     int64
#  1   pavadinimas            27 non-null     object
#  2   matavimo_vnt           27 non-null     object
#  3   vienetu                27 non-null     int64
#  4   vnt_kaina              27 non-null     int64
#  5   saskaitos_fakturos_id  27 non-null     int64
#  6   nuolaida               27 non-null     int64
#  7   bendra_kaina           27 non-null     int64
# dtypes: int64(6), object(2)
# memory usage: 1.8+ KB

# %%
# duomenys['idsf_paslaugos_prekes']
# duomenys['bendra_kaina']

plt.plot(duomenys['idsf_paslaugos_prekes'], duomenys['bendra_kaina'])

plt.show()

# %%
duomenys['bendra_kaina'].sum()
# Out:
# 71280

# %%
duomenys['bendra_kaina'].mean()
# Out:
# 2640.0

# %%
duomenys['bendra_kaina'].max()
# Out:
# 6400

# %%
duomenys['bendra_kaina'].min()
# Out:
# 300

# %%
duomenys['vienetu'].max()
# Out:
# 160

# %%
duomenys['bendra_kaina'].count()
# Out:
# 27

# %%
duomenys.iloc[0]
# Out:
# idsf_paslaugos_prekes                   1
# pavadinimas              Dizaino piešimas
# matavimo_vnt                         val.
# vienetu                               120
# vnt_kaina                              40
# saskaitos_fakturos_id                   1
# nuolaida                                0
# bendra_kaina                         4800
# Name: 0, dtype: object

# %%
duomenys.iloc[[0]]
# Out:
#    idsf_paslaugos_prekes       pavadinimas matavimo_vnt  vienetu  vnt_kaina  \
# 0                      1  Dizaino piešimas         val.      120         40
#
#    saskaitos_fakturos_id  nuolaida  bendra_kaina
# 0                      1         0          4800

# %%
duomenys.loc[duomenys['vienetu'] >= 100]
# Out:
#     idsf_paslaugos_prekes            pavadinimas matavimo_vnt  vienetu  \
# 0                       1       Dizaino piešimas         val.      120
# 1                       2  Dizaino programavimas         val.      120
# 2                       3          Programavimas         val.      160
# 4                       5          Programavimas         val.      160
# 6                       7          Programavimas         val.      160
# 8                       9          Programavimas         val.      160
# 10                     11          Programavimas         val.      100
# 15                     16  Dizaino programavimas         val.      120
# 17                     18          Programavimas         val.      100
#
#     vnt_kaina  saskaitos_fakturos_id  nuolaida  bendra_kaina
# 0          40                      1         0          4800
# 1          40                      1         0          4800
# 2          40                      2         0          6400
# ...

# %%
duomenys.loc[ duomenys['bendra_kaina'] <= 500 ]
# Out:
#     idsf_paslaugos_prekes          pavadinimas matavimo_vnt  vienetu  \
# 3                       4           Testavimas         val.       16
# 25                     26           Testavimas         val.       10
# 26                     27  Projekto talpinimas         val.       10
#
#     vnt_kaina  saskaitos_fakturos_id  nuolaida  bendra_kaina
# 3          30                      2         0           480
# 25         30                     12         0           300
# 26         30                     12         0           300

# %%
# and - &
# or - |
# not - !

# %%
duomenys.loc[ (duomenys['vienetu'] <= 100) & (duomenys['vienetu'] >= 50) ]
# Out:
#     idsf_paslaugos_prekes              pavadinimas matavimo_vnt  vienetu  \
# 10                     11            Programavimas         val.      100
# 12                     13  Dokumentacijos rengimas         val.       50
# 14                     15         Dizaino piešimas         val.       80
# 17                     18            Programavimas         val.      100
# 21                     22         Dizaino piešimas         val.       80
# 22                     23    Dizaino programavimas         val.       80
# 24                     25            Programavimas         val.       80
#
#     vnt_kaina  saskaitos_fakturos_id  nuolaida  bendra_kaina
# 10         40                      6         0          4000
# 12         30                      6         0          1500
# 14         40                      7         0          3200
# 17         40                      9         0          4000
# 21         40                     11         0          3200
# ...

# %%
duomenys.loc[ (duomenys['pavadinimas'] == 'Dizaino piešimas') | (duomenys['pavadinimas'] == 'Dizaino programavimas') ]
# Out:
#     idsf_paslaugos_prekes            pavadinimas matavimo_vnt  vienetu  \
# 0                       1       Dizaino piešimas         val.      120
# 1                       2  Dizaino programavimas         val.      120
# 14                     15       Dizaino piešimas         val.       80
# 15                     16  Dizaino programavimas         val.      120
# 21                     22       Dizaino piešimas         val.       80
# 22                     23  Dizaino programavimas         val.       80
#
#     vnt_kaina  saskaitos_fakturos_id  nuolaida  bendra_kaina
# 0          40                      1         0          4800
# 1          40                      1         0          4800
# 14         40                      7         0          3200
# 15         40                      7         0          4800
# 21         40                     11         0          3200
# 22         40                     11         0          3200

# %%
# duomenys.loc[duomenys['bendra_kaina'] >= 3000].sort_values('bendra_kaina')
duomenys.loc[duomenys['bendra_kaina'] >= 3000].sort_values('bendra_kaina', ascending=False)
# duomenys.sort_values('bendra_kaina', ascending=False)
# Out:
#     idsf_paslaugos_prekes            pavadinimas matavimo_vnt  vienetu  \
# 2                       3          Programavimas         val.      160
# 4                       5          Programavimas         val.      160
# 6                       7          Programavimas         val.      160
# 8                       9          Programavimas         val.      160
# 0                       1       Dizaino piešimas         val.      120
# 1                       2  Dizaino programavimas         val.      120
# 15                     16  Dizaino programavimas         val.      120
# 10                     11          Programavimas         val.      100
# 17                     18          Programavimas         val.      100
# 14                     15       Dizaino piešimas         val.       80
# 21                     22       Dizaino piešimas         val.       80
# 22                     23  Dizaino programavimas         val.       80
# ...

# %%
duomenys.loc[duomenys['bendra_kaina'] >= 3000].sort_values(['bendra_kaina', 'idsf_paslaugos_prekes'], ascending=[False, False])
# Out:
#     idsf_paslaugos_prekes            pavadinimas matavimo_vnt  vienetu  \
# 8                       9          Programavimas         val.      160
# 6                       7          Programavimas         val.      160
# 4                       5          Programavimas         val.      160
# 2                       3          Programavimas         val.      160
# 15                     16  Dizaino programavimas         val.      120
# 1                       2  Dizaino programavimas         val.      120
# 0                       1       Dizaino piešimas         val.      120
# 17                     18          Programavimas         val.      100
# 10                     11          Programavimas         val.      100
# 24                     25          Programavimas         val.       80
# 22                     23  Dizaino programavimas         val.       80
# 21                     22       Dizaino piešimas         val.       80
# ...

# %%
duomenys.groupby('pavadinimas')['bendra_kaina'].sum()
# Out:
# pavadinimas
# Avansas                        1000
# Dizaino piešimas              11200
# Dizaino programavimas         12800
# Dokumentacijos rengimas        1500
# Programavimas                 36800
# Projekto parengimas darbui      900
# Projekto talpinimas             900
# Testavimas                     6180
# Name: bendra_kaina, dtype: int64

# %%
paslaugu_kainos = duomenys.groupby('pavadinimas')['bendra_kaina'].sum()
paslaugu_kainos
# Out:
# pavadinimas
# Avansas                        1000
# Dizaino piešimas              11200
# Dizaino programavimas         12800
# Dokumentacijos rengimas        1500
# Programavimas                 36800
# Projekto parengimas darbui      900
# Projekto talpinimas             900
# Testavimas                     6180
# Name: bendra_kaina, dtype: int64

# %%
paslaugu_kainos.plot(kind='bar')
# Out:
# <Axes: xlabel='pavadinimas'>
