# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/blaztoma/pitono-pamokos/blob/main/lectures/10%20-%20Practice%201/Practice_1.ipynb)

# %% [markdown]
# # Practice (1)

# %% [markdown]
# ## Task objective
#
# Calculate how many loaves of bread the bakery will be able to bake per day, whether it will manage to fulfill all daily orders, and calculate how much profit it will earn from them.

# %% [markdown]
# ## Data
#
# Defined data:
#
# - Working hours per day - 8 hours.
#
# Your input data:
#
# - How many loaves an employee can bake per hour.
# - How many employees the bakery has.
# - Cost price of one loaf.
# - Selling price of one loaf.
# - How many loaves the bakery needs to bake that day (orders).

# %%
# Create variables and assign information to them...

# %% [markdown]
# ## Calculations

# %% [markdown]
# Calculate how many loaves of bread the bakery will manage to bake in one working day.

# %%
# Write your code here...

# %% [markdown]
# Calculate the total cost of all loaves, the revenue from selling them, and the profit portion from that.

# %%
# Write your code here...

# %% [markdown]
# Check if the bakery will manage to bake all orders for that day. If not, calculate how many loaves it won't manage to bake.

# %%
# Write your code here...

# %% [markdown]
# Additionally, consider that you can only get revenue and profit from sold loaves.

# %%
# Write your code here...
